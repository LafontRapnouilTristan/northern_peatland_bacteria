# %%
##########################################################################################################################################
######################## This script extracts covariates values at each of the data point position #########################
##########################################################################################################################################

# %%
import ee # Import the Python API package
import geemap # The geemap Python package is built upon the ipyleaflet and folium packages and implements several methods for interacting with Earth Engine data layer
ee.Authenticate() # Authenticate to the Earth Engine servers
ee.Initialize() # Initialize the API
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=EyiRtW7AU3pg2dnvC6RPoQGHI2mW5ptv2SA72NM2Kgg&tc=W_FD8BAojhkfrJEWXqx6G6Tr8Q8mJijEq1DXeA-DNmQ&cc=JjWdnYiRnTZHOWDbQpnRJgHXeKmtKeVXuQlnramUK8o>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=EyiRtW7AU3pg2dnvC6RPoQGHI2mW5ptv2SA72NM2Kgg&tc=W_FD8BAojhkfrJEWXqx6G6Tr8Q8mJijEq1DXeA-DNmQ&cc=JjWdnYiRnTZHOWDbQpnRJgHXeKmtKeVXuQlnramUK8o</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AeaYSHAQVyZ-dxIuF0cigg0huK8zKNp3cilNCRkCEf8xW39bPqqzexiUr3U
# ...

# %%
# Loading sampling points stored in personnal repository
PtsToSample = ee.FeatureCollection('projects/ee-romainwalcker/assets/MAPP_site_coord')
print('Size of the data collection',PtsToSample.size().getInfo())
# Out:
# Size of the data collection 231

# %%
# Create a map
Map1 = geemap.Map(center=[0,0], zoom=2)
Map1.addLayer(PtsToSample, {},'Sampling points')
Map1
# Out:
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Toggl…

# %%
# Computing TerraClim
# Climate variables long term mean
TerraClim_lt = ee.ImageCollection('IDAHO_EPSCOR/TERRACLIMATE').filter(ee.Filter.date('2016-01-01', '2021-01-01'))
aet_lt = TerraClim_lt.select('aet').mean().multiply(0.1).unmask(-9999).rename('aet_lt')# Actual evapotranspiration in milimeters
def_lt = TerraClim_lt.select('def').mean().multiply(0.1).unmask(-9999).rename('def_lt')# Climate water deficit in milimeters
pdsi_lt = TerraClim_lt.select('pdsi').mean().multiply(0.01).unmask(-9999).rename('pdsi_lt')# Palmer Drought Severity Index
pet_lt = TerraClim_lt.select('pet').mean().multiply(0.1).unmask(-9999).rename('pet_lt')# Reference evapotranspiration in milimeters
pr_lt = TerraClim_lt.select('pr').mean().unmask(-9999).rename('pr_lt')# Precipitation accumulation in milimeters
srad_lt = TerraClim_lt.select('srad').mean().multiply(0.1).unmask(-9999).rename('srad_lt')# Downward surface shortwave radiation in W/m^2
swe_lt = TerraClim_lt.select('swe').mean().unmask(-9999).rename('swe_lt')# Snow water equivalent in milimeters
tmmn_lt = TerraClim_lt.select('tmmn').mean().multiply(0.1).unmask(-9999).rename('tmmn_lt')# Minimum temperature in °C
tmmx_lt = TerraClim_lt.select('tmmx').mean().multiply(0.1).unmask(-9999).rename('tmmx_lt')# Maximum temperature in °C
vap_lt = TerraClim_lt.select('vap').mean().multiply(0.001).unmask(-9999).rename('vap_lt')# Vapor pressure in kPa
vpd_lt = TerraClim_lt.select('vpd').mean().multiply(0.01).unmask(-9999).rename('vpd_lt')# Vapor pressure deficit in kPa
moist_lt = TerraClim_lt.select('soil').mean().multiply(0.1).unmask(-9999).rename('moist_lt')# Soil moisture, derived using a one-dimensional soil water balance model in milimeters

# Monthly climate variables 2021
# March
TerraClim_03 = ee.ImageCollection('IDAHO_EPSCOR/TERRACLIMATE').filter(ee.Filter.date('2021-03-01', '2021-04-01'))
aet_03 = TerraClim_03.select('aet').mean().multiply(0.1).unmask(-9999).rename('aet_03')# Actual evapotranspiration in milimeters
def_03 = TerraClim_03.select('def').mean().multiply(0.1).unmask(-9999).rename('def_03')# Climate water deficit in milimeters
pdsi_03 = TerraClim_03.select('pdsi').mean().multiply(0.01).unmask(-9999).rename('pdsi_03')# Palmer Drought Severity Index
pet_03 = TerraClim_03.select('pet').mean().multiply(0.1).unmask(-9999).rename('pet_03')# Reference evapotranspiration in milimeters
pr_03 = TerraClim_03.select('pr').mean().unmask(-9999).rename('pr_03')# Precipitation accumulation in milimeters
srad_03 = TerraClim_03.select('srad').mean().multiply(0.1).unmask(-9999).rename('srad_03')# Downward surface shortwave radiation in W/m^2
swe_03 = TerraClim_03.select('swe').mean().unmask(-9999).rename('swe_03')# Snow water equivalent in milimeters
tmmn_03 = TerraClim_03.select('tmmn').mean().multiply(0.1).unmask(-9999).rename('tmmn_03')# Minimum temperature in °C
tmmx_03 = TerraClim_03.select('tmmx').mean().multiply(0.1).unmask(-9999).rename('tmmx_03')# Maximum temperature in °C
vap_03 = TerraClim_03.select('vap').mean().multiply(0.001).unmask(-9999).rename('vap_03')# Vapor pressure in kPa
vpd_03 = TerraClim_03.select('vpd').mean().multiply(0.01).unmask(-9999).rename('vpd_03')# Vapor pressure deficit in kPa
moist_03 = TerraClim_03.select('soil').mean().multiply(0.1).unmask(-9999).rename('moist_03')# Soil moisture, derived using a one-dimensional soil water balance model in milimeters

# April
TerraClim_04 = ee.ImageCollection('IDAHO_EPSCOR/TERRACLIMATE').filter(ee.Filter.date('2021-04-01', '2021-05-01'))
aet_04 = TerraClim_04.select('aet').mean().multiply(0.1).unmask(-9999).rename('aet_04')# Actual evapotranspiration in milimeters
def_04 = TerraClim_04.select('def').mean().multiply(0.1).unmask(-9999).rename('def_04')# Climate water deficit in milimeters
pdsi_04 = TerraClim_04.select('pdsi').mean().multiply(0.01).unmask(-9999).rename('pdsi_04')# Palmer Drought Severity Index
pet_04 = TerraClim_04.select('pet').mean().multiply(0.1).unmask(-9999).rename('pet_04')# Reference evapotranspiration in milimeters
pr_04 = TerraClim_04.select('pr').mean().unmask(-9999).rename('pr_04')# Precipitation accumulation in milimeters
srad_04 = TerraClim_04.select('srad').mean().multiply(0.1).unmask(-9999).rename('srad_04')# Downward surface shortwave radiation in W/m^2
swe_04 = TerraClim_04.select('swe').mean().unmask(-9999).rename('swe_04')# Snow water equivalent in milimeters
tmmn_04 = TerraClim_04.select('tmmn').mean().multiply(0.1).unmask(-9999).rename('tmmn_04')# Minimum temperature in °C
tmmx_04 = TerraClim_04.select('tmmx').mean().multiply(0.1).unmask(-9999).rename('tmmx_04')# Maximum temperature in °C
vap_04 = TerraClim_04.select('vap').mean().multiply(0.001).unmask(-9999).rename('vap_04')# Vapor pressure in kPa
vpd_04 = TerraClim_04.select('vpd').mean().multiply(0.01).unmask(-9999).rename('vpd_04')# Vapor pressure deficit in kPa
moist_04 = TerraClim_04.select('soil').mean().multiply(0.1).unmask(-9999).rename('moist_04')# Soil moisture, derived using a one-dimensional soil water balance model in milimeters

# May
TerraClim_05 = ee.ImageCollection('IDAHO_EPSCOR/TERRACLIMATE').filter(ee.Filter.date('2021-05-01', '2021-06-01'))
aet_05 = TerraClim_05.select('aet').mean().multiply(0.1).unmask(-9999).rename('aet_05')# Actual evapotranspiration in milimeters
def_05 = TerraClim_05.select('def').mean().multiply(0.1).unmask(-9999).rename('def_05')# Climate water deficit in milimeters
pdsi_05 = TerraClim_05.select('pdsi').mean().multiply(0.01).unmask(-9999).rename('pdsi_05')# Palmer Drought Severity Index
pet_05 = TerraClim_05.select('pet').mean().multiply(0.1).unmask(-9999).rename('pet_05')# Reference evapotranspiration in milimeters
pr_05 = TerraClim_05.select('pr').mean().unmask(-9999).rename('pr_05')# Precipitation accumulation in milimeters
srad_05 = TerraClim_05.select('srad').mean().multiply(0.1).unmask(-9999).rename('srad_05')# Downward surface shortwave radiation in W/m^2
swe_05 = TerraClim_05.select('swe').mean().unmask(-9999).rename('swe_05')# Snow water equivalent in milimeters
tmmn_05 = TerraClim_05.select('tmmn').mean().multiply(0.1).unmask(-9999).rename('tmmn_05')# Minimum temperature in °C
tmmx_05 = TerraClim_05.select('tmmx').mean().multiply(0.1).unmask(-9999).rename('tmmx_05')# Maximum temperature in °C
vap_05 = TerraClim_05.select('vap').mean().multiply(0.001).unmask(-9999).rename('vap_05')# Vapor pressure in kPa
vpd_05 = TerraClim_05.select('vpd').mean().multiply(0.01).unmask(-9999).rename('vpd_05')# Vapor pressure deficit in kPa
moist_05 = TerraClim_05.select('soil').mean().multiply(0.1).unmask(-9999).rename('moist_05')# Soil moisture, derived using a one-dimensional soil water balance model in milimeters

# June
TerraClim_06 = ee.ImageCollection('IDAHO_EPSCOR/TERRACLIMATE').filter(ee.Filter.date('2021-06-01', '2021-07-01'))
aet_06 = TerraClim_06.select('aet').mean().multiply(0.1).unmask(-9999).rename('aet_06')# Actual evapotranspiration in milimeters
def_06 = TerraClim_06.select('def').mean().multiply(0.1).unmask(-9999).rename('def_06')# Climate water deficit in milimeters
pdsi_06 = TerraClim_06.select('pdsi').mean().multiply(0.01).unmask(-9999).rename('pdsi_06')# Palmer Drought Severity Index
pet_06 = TerraClim_06.select('pet').mean().multiply(0.1).unmask(-9999).rename('pet_06')# Reference evapotranspiration in milimeters
pr_06 = TerraClim_06.select('pr').mean().unmask(-9999).rename('pr_06')# Precipitation accumulation in milimeters
srad_06 = TerraClim_06.select('srad').mean().multiply(0.1).unmask(-9999).rename('srad_06')# Downward surface shortwave radiation in W/m^2
swe_06 = TerraClim_06.select('swe').mean().unmask(-9999).rename('swe_06')# Snow water equivalent in milimeters
tmmn_06 = TerraClim_06.select('tmmn').mean().multiply(0.1).unmask(-9999).rename('tmmn_06')# Minimum temperature in °C
tmmx_06 = TerraClim_06.select('tmmx').mean().multiply(0.1).unmask(-9999).rename('tmmx_06')# Maximum temperature in °C
vap_06 = TerraClim_06.select('vap').mean().multiply(0.001).unmask(-9999).rename('vap_06')# Vapor pressure in kPa
vpd_06 = TerraClim_06.select('vpd').mean().multiply(0.01).unmask(-9999).rename('vpd_06')# Vapor pressure deficit in kPa
moist_06 = TerraClim_06.select('soil').mean().multiply(0.1).unmask(-9999).rename('moist_06')# Soil moisture, derived using a one-dimensional soil water balance model in milimeters

# July
TerraClim_07 = ee.ImageCollection('IDAHO_EPSCOR/TERRACLIMATE').filter(ee.Filter.date('2021-07-01', '2021-08-01'))
aet_07 = TerraClim_07.select('aet').mean().multiply(0.1).unmask(-9999).rename('aet_07')# Actual evapotranspiration in milimeters
def_07 = TerraClim_07.select('def').mean().multiply(0.1).unmask(-9999).rename('def_07')# Climate water deficit in milimeters
pdsi_07 = TerraClim_07.select('pdsi').mean().multiply(0.01).unmask(-9999).rename('pdsi_07')# Palmer Drought Severity Index
pet_07 = TerraClim_07.select('pet').mean().multiply(0.1).unmask(-9999).rename('pet_07')# Reference evapotranspiration in milimeters
pr_07 = TerraClim_07.select('pr').mean().unmask(-9999).rename('pr_07')# Precipitation accumulation in milimeters
srad_07 = TerraClim_07.select('srad').mean().multiply(0.1).unmask(-9999).rename('srad_07')# Downward surface shortwave radiation in W/m^2
swe_07 = TerraClim_07.select('swe').mean().unmask(-9999).rename('swe_07')# Snow water equivalent in milimeters
tmmn_07 = TerraClim_07.select('tmmn').mean().multiply(0.1).unmask(-9999).rename('tmmn_07')# Minimum temperature in °C
tmmx_07 = TerraClim_07.select('tmmx').mean().multiply(0.1).unmask(-9999).rename('tmmx_07')# Maximum temperature in °C
vap_07 = TerraClim_07.select('vap').mean().multiply(0.001).unmask(-9999).rename('vap_07')# Vapor pressure in kPa
vpd_07 = TerraClim_07.select('vpd').mean().multiply(0.01).unmask(-9999).rename('vpd_07')# Vapor pressure deficit in kPa
moist_07 = TerraClim_07.select('soil').mean().multiply(0.1).unmask(-9999).rename('moist_07')# Soil moisture, derived using a one-dimensional soil water balance model in milimeters

# August
TerraClim_08 = ee.ImageCollection('IDAHO_EPSCOR/TERRACLIMATE').filter(ee.Filter.date('2021-08-01', '2021-09-01'))
aet_08 = TerraClim_08.select('aet').mean().multiply(0.1).unmask(-9999).rename('aet_08')# Actual evapotranspiration in milimeters
def_08 = TerraClim_08.select('def').mean().multiply(0.1).unmask(-9999).rename('def_08')# Climate water deficit in milimeters
pdsi_08 = TerraClim_08.select('pdsi').mean().multiply(0.01).unmask(-9999).rename('pdsi_08')# Palmer Drought Severity Index
pet_08 = TerraClim_08.select('pet').mean().multiply(0.1).unmask(-9999).rename('pet_08')# Reference evapotranspiration in milimeters
pr_08 = TerraClim_08.select('pr').mean().unmask(-9999).rename('pr_08')# Precipitation accumulation in milimeters
srad_08 = TerraClim_08.select('srad').mean().multiply(0.1).unmask(-9999).rename('srad_08')# Downward surface shortwave radiation in W/m^2
swe_08 = TerraClim_08.select('swe').mean().unmask(-9999).rename('swe_08')# Snow water equivalent in milimeters
tmmn_08 = TerraClim_08.select('tmmn').mean().multiply(0.1).unmask(-9999).rename('tmmn_08')# Minimum temperature in °C
tmmx_08 = TerraClim_08.select('tmmx').mean().multiply(0.1).unmask(-9999).rename('tmmx_08')# Maximum temperature in °C
vap_08 = TerraClim_08.select('vap').mean().multiply(0.001).unmask(-9999).rename('vap_08')# Vapor pressure in kPa
vpd_08 = TerraClim_08.select('vpd').mean().multiply(0.01).unmask(-9999).rename('vpd_08')# Vapor pressure deficit in kPa
moist_08 = TerraClim_08.select('soil').mean().multiply(0.1).unmask(-9999).rename('moist_08')# Soil moisture, derived using a one-dimensional soil water balance model in milimeters

# September
TerraClim_09 = ee.ImageCollection('IDAHO_EPSCOR/TERRACLIMATE').filter(ee.Filter.date('2021-09-01', '2021-10-01'))
aet_09 = TerraClim_09.select('aet').mean().multiply(0.1).unmask(-9999).rename('aet_09')# Actual evapotranspiration in milimeters
def_09 = TerraClim_09.select('def').mean().multiply(0.1).unmask(-9999).rename('def_09')# Climate water deficit in milimeters
pdsi_09 = TerraClim_09.select('pdsi').mean().multiply(0.01).unmask(-9999).rename('pdsi_09')# Palmer Drought Severity Index
pet_09 = TerraClim_09.select('pet').mean().multiply(0.1).unmask(-9999).rename('pet_09')# Reference evapotranspiration in milimeters
pr_09 = TerraClim_09.select('pr').mean().unmask(-9999).rename('pr_09')# Precipitation accumulation in milimeters
srad_09 = TerraClim_09.select('srad').mean().multiply(0.1).unmask(-9999).rename('srad_09')# Downward surface shortwave radiation in W/m^2
swe_09 = TerraClim_09.select('swe').mean().unmask(-9999).rename('swe_09')# Snow water equivalent in milimeters
tmmn_09 = TerraClim_09.select('tmmn').mean().multiply(0.1).unmask(-9999).rename('tmmn_09')# Minimum temperature in °C
tmmx_09 = TerraClim_09.select('tmmx').mean().multiply(0.1).unmask(-9999).rename('tmmx_09')# Maximum temperature in °C
vap_09 = TerraClim_09.select('vap').mean().multiply(0.001).unmask(-9999).rename('vap_09')# Vapor pressure in kPa
vpd_09 = TerraClim_09.select('vpd').mean().multiply(0.01).unmask(-9999).rename('vpd_09')# Vapor pressure deficit in kPa
moist_09 = TerraClim_09.select('soil').mean().multiply(0.1).unmask(-9999).rename('moist_09')# Soil moisture, derived using a one-dimensional soil water balance model in milimeters

# October
TerraClim_10 = ee.ImageCollection('IDAHO_EPSCOR/TERRACLIMATE').filter(ee.Filter.date('2021-10-01', '2021-11-01'))
aet_10 = TerraClim_10.select('aet').mean().multiply(0.1).unmask(-9999).rename('aet_10')# Actual evapotranspiration in milimeters
def_10 = TerraClim_10.select('def').mean().multiply(0.1).unmask(-9999).rename('def_10')# Climate water deficit in milimeters
pdsi_10 = TerraClim_10.select('pdsi').mean().multiply(0.01).unmask(-9999).rename('pdsi_10')# Palmer Drought Severity Index
pet_10 = TerraClim_10.select('pet').mean().multiply(0.1).unmask(-9999).rename('pet_10')# Reference evapotranspiration in milimeters
pr_10 = TerraClim_10.select('pr').mean().unmask(-9999).rename('pr_10')# Precipitation accumulation in milimeters
srad_10 = TerraClim_10.select('srad').mean().multiply(0.1).unmask(-9999).rename('srad_10')# Downward surface shortwave radiation in W/m^2
swe_10 = TerraClim_10.select('swe').mean().unmask(-9999).rename('swe_10')# Snow water equivalent in milimeters
tmmn_10 = TerraClim_10.select('tmmn').mean().multiply(0.1).unmask(-9999).rename('tmmn_10')# Minimum temperature in °C
tmmx_10 = TerraClim_10.select('tmmx').mean().multiply(0.1).unmask(-9999).rename('tmmx_10')# Maximum temperature in °C
vap_10 = TerraClim_10.select('vap').mean().multiply(0.001).unmask(-9999).rename('vap_10')# Vapor pressure in kPa
vpd_10 = TerraClim_10.select('vpd').mean().multiply(0.01).unmask(-9999).rename('vpd_10')# Vapor pressure deficit in kPa
moist_10 = TerraClim_10.select('soil').mean().multiply(0.1).unmask(-9999).rename('moist_10')# Soil moisture, derived using a one-dimensional soil water balance model in milimeters

# Exporting TerraClim part
compositeOfInterest0 = aet_lt.addBands(def_lt).addBands(pdsi_lt).addBands(pet_lt).addBands(pr_lt).addBands(srad_lt).addBands(swe_lt).addBands(tmmn_lt).addBands(tmmx_lt).addBands(vap_lt).addBands(vpd_lt).addBands(moist_lt)\
.addBands(aet_03).addBands(def_03).addBands(pdsi_03).addBands(pet_03).addBands(pr_03).addBands(srad_03).addBands(swe_03).addBands(tmmn_03).addBands(tmmx_03).addBands(vap_03).addBands(vpd_03).addBands(moist_03)\
.addBands(aet_04).addBands(def_04).addBands(pdsi_04).addBands(pet_04).addBands(pr_04).addBands(srad_04).addBands(swe_04).addBands(tmmn_04).addBands(tmmx_04).addBands(vap_04).addBands(vpd_04).addBands(moist_04)\
.addBands(aet_05).addBands(def_05).addBands(pdsi_05).addBands(pet_05).addBands(pr_05).addBands(srad_05).addBands(swe_05).addBands(tmmn_05).addBands(tmmx_05).addBands(vap_05).addBands(vpd_05).addBands(moist_05)\
.addBands(aet_06).addBands(def_06).addBands(pdsi_06).addBands(pet_06).addBands(pr_06).addBands(srad_06).addBands(swe_06).addBands(tmmn_06).addBands(tmmx_06).addBands(vap_06).addBands(vpd_06).addBands(moist_06)\
.addBands(aet_07).addBands(def_07).addBands(pdsi_07).addBands(pet_07).addBands(pr_07).addBands(srad_07).addBands(swe_07).addBands(tmmn_07).addBands(tmmx_07).addBands(vap_07).addBands(vpd_07).addBands(moist_07)\
.addBands(aet_08).addBands(def_08).addBands(pdsi_08).addBands(pet_08).addBands(pr_08).addBands(srad_08).addBands(swe_08).addBands(tmmn_08).addBands(tmmx_08).addBands(vap_08).addBands(vpd_08).addBands(moist_08)\
.addBands(aet_09).addBands(def_09).addBands(pdsi_09).addBands(pet_09).addBands(pr_09).addBands(srad_09).addBands(swe_09).addBands(tmmn_09).addBands(tmmx_09).addBands(vap_09).addBands(vpd_09).addBands(moist_09)\
.addBands(aet_10).addBands(def_10).addBands(pdsi_10).addBands(pet_10).addBands(pr_10).addBands(srad_10).addBands(swe_10).addBands(tmmn_10).addBands(tmmx_10).addBands(vap_10).addBands(vpd_10).addBands(moist_10)

# Sampling
PtsSampled0 = compositeOfInterest0.sampleRegions(collection= PtsToSample,scale= 250)

# Export to drive
taskParams = {'driveFolder': 'TRISTAN','fileFormat': 'CSV'}
task = ee.batch.Export.table.toDrive(PtsSampled0,str('PtsSampled0'),**taskParams)
task.start()

# %%
# Computing OpenLandMap soil variables
USDA4A1H_M = ee.Image("OpenLandMap/SOL/SOL_BULKDENS-FINEEARTH_USDA-4A1H_M/v02")
bulk = USDA4A1H_M.select('b0').multiply(10).unmask(-9999).rename('bulk')# Soil bulk density at 0 cm depth in kg/m^3
USDA3A1A1A_M = ee.Image("OpenLandMap/SOL/SOL_CLAY-WFRACTION_USDA-3A1A1A_M/v02")
clay = USDA3A1A1A_M.select('b0').multiply(100).unmask(-9999).rename('clay')# Clay content at 0 cm depth in % (kg / kg)
USDA6A1C_M = ee.Image("OpenLandMap/SOL/SOL_ORGANIC-CARBON_USDA-6A1C_M/v02")
soc = USDA6A1C_M.select('b0').multiply(5).unmask(-9999).rename('soc')# Soil organic carbon content at 0 cm depth in g/kg
USDA4C1A2A_M = ee.Image("OpenLandMap/SOL/SOL_PH-H2O_USDA-4C1A2A_M/v02")
ph = USDA4C1A2A_M.select('b0').multiply(10).unmask(-9999).rename('ph')# Soil pH in H2O at 0 cm depth
USDA4B1C_M = ee.Image("OpenLandMap/SOL/SOL_WATERCONTENT-33KPA_USDA-4B1C_M/v01")
water = USDA4B1C_M.select('b0').unmask(-9999).rename('water')# Soil water content in %

# Exporting OpenLandMap part
compositeOfInterest1 = bulk.addBands(clay).addBands(soc).addBands(ph).addBands(water)

# Sampling
PtsSampled1 = compositeOfInterest1.sampleRegions(collection= PtsToSample,scale= 250)

# Export to drive
taskParams = {'driveFolder': 'TRISTAN','fileFormat': 'CSV'}
task = ee.batch.Export.table.toDrive(PtsSampled1,str('PtsSampled1'),**taskParams)
task.start()

# %%
# Computing SMAP soil variables

# Time average
SMAP_lt = ee.ImageCollection('NASA/SMAP/SPL3SMP_E/005').filter(ee.Filter.date('2016-01-01', '2021-01-01'))
soil_moisture_lt = SMAP_lt.select('soil_moisture_am').mean().unmask(-9999).rename('soil_moisture_lt')# Top layer soil moisture (0-5 cm) in volume fraction

# March
SMAP_03 = ee.ImageCollection('NASA/SMAP/SPL3SMP_E/005').filter(ee.Filter.date('2021-03-01', '2021-04-01'))
soil_moisture_03 = SMAP_03.select('soil_moisture_am').mean().unmask(-9999).rename('soil_moisture_03')# Top layer soil moisture (0-5 cm) in volume fraction

# April
SMAP_04 = ee.ImageCollection('NASA/SMAP/SPL3SMP_E/005').filter(ee.Filter.date('2021-04-01', '2021-05-01'))
soil_moisture_04 = SMAP_04.select('soil_moisture_am').mean().unmask(-9999).rename('soil_moisture_04')# Top layer soil moisture (0-5 cm) in volume fraction

# May
SMAP_05 = ee.ImageCollection('NASA/SMAP/SPL3SMP_E/005').filter(ee.Filter.date('2021-05-01', '2021-06-01'))
soil_moisture_05 = SMAP_05.select('soil_moisture_am').mean().unmask(-9999).rename('soil_moisture_05')# Top layer soil moisture (0-5 cm) in volume fraction

# June
SMAP_06 = ee.ImageCollection('NASA/SMAP/SPL3SMP_E/005').filter(ee.Filter.date('2021-06-01', '2021-07-01'))
soil_moisture_06 = SMAP_06.select('soil_moisture_am').mean().unmask(-9999).rename('soil_moisture_06')# Top layer soil moisture (0-5 cm) in volume fraction

# July
SMAP_07 = ee.ImageCollection('NASA/SMAP/SPL3SMP_E/005').filter(ee.Filter.date('2021-07-01', '2021-08-01'))
soil_moisture_07 = SMAP_07.select('soil_moisture_am').mean().unmask(-9999).rename('soil_moisture_07')# Top layer soil moisture (0-5 cm) in volume fraction

# August
SMAP_08 = ee.ImageCollection('NASA/SMAP/SPL3SMP_E/005').filter(ee.Filter.date('2021-08-01', '2021-09-01'))
soil_moisture_08 = SMAP_08.select('soil_moisture_am').mean().unmask(-9999).rename('soil_moisture_08')# Top layer soil moisture (0-5 cm) in volume fraction


# September
SMAP_09 = ee.ImageCollection('NASA/SMAP/SPL3SMP_E/005').filter(ee.Filter.date('2021-09-01', '2021-10-01'))
soil_moisture_09 = SMAP_09.select('soil_moisture_am').mean().unmask(-9999).rename('soil_moisture_09')# Top layer soil moisture (0-5 cm) in volume fraction


# October
SMAP_10 = ee.ImageCollection('NASA/SMAP/SPL3SMP_E/005').filter(ee.Filter.date('2021-10-01', '2021-11-01'))
soil_moisture_10 = SMAP_10.select('soil_moisture_am').mean().unmask(-9999).rename('soil_moisture_10')# Top layer soil moisture (0-5 cm) in volume fraction


# Exporting SMAP and Topographic parts
compositeOfInterest2 = soil_moisture_lt.addBands(soil_moisture_03).addBands(soil_moisture_04).addBands(soil_moisture_05)\
.addBands(soil_moisture_06).addBands(soil_moisture_07).addBands(soil_moisture_08).addBands(soil_moisture_09).addBands(soil_moisture_10)

# Sampling
PtsSampled2 = compositeOfInterest2.sampleRegions(collection= PtsToSample,scale= 250)

# Export to drive
taskParams = {'driveFolder': 'TRISTAN','fileFormat': 'CSV'}
task = ee.batch.Export.table.toDrive(PtsSampled2,str('PtsSampled2'),**taskParams)
task.start()

# %%
# Computing VIs
# Long-term
MOD13Q1_lt = ee.ImageCollection('MODIS/006/MOD13Q1').filter(ee.Filter.date('2016-01-01', '2021-01-01'))
ndvi_lt = MOD13Q1_lt.select('NDVI').mean().multiply(0.0001).unmask(-9999).rename('ndvi_lt')# Normalized Difference Vegetation Index
evi_lt = MOD13Q1_lt.select('EVI').mean().multiply(0.0001).unmask(-9999).rename('evi_lt')# Enhanced Vegetation Index

# March
MOD13Q1_03 = ee.ImageCollection('MODIS/006/MOD13Q1').filter(ee.Filter.date('2021-03-01', '2021-04-01'))
ndvi_03 = MOD13Q1_03.select('NDVI').mean().multiply(0.0001).unmask(-9999).rename('ndvi_03')# Normalized Difference Vegetation Index
evi_03 = MOD13Q1_03.select('EVI').mean().multiply(0.0001).unmask(-9999).rename('evi_03')# Enhanced Vegetation Index

# April
MOD13Q1_04 = ee.ImageCollection('MODIS/006/MOD13Q1').filter(ee.Filter.date('2021-04-01', '2021-05-01'))
ndvi_04 = MOD13Q1_04.select('NDVI').mean().multiply(0.0001).unmask(-9999).rename('ndvi_04')# Normalized Difference Vegetation Index
evi_04 = MOD13Q1_04.select('EVI').mean().multiply(0.0001).unmask(-9999).rename('evi_04')# Enhanced Vegetation Index

# May
MOD13Q1_05 = ee.ImageCollection('MODIS/006/MOD13Q1').filter(ee.Filter.date('2021-05-01', '2021-06-01'))
ndvi_05 = MOD13Q1_05.select('NDVI').mean().multiply(0.0001).unmask(-9999).rename('ndvi_05')# Normalized Difference Vegetation Index
evi_05 = MOD13Q1_05.select('EVI').mean().multiply(0.0001).unmask(-9999).rename('evi_05')# Enhanced Vegetation Index

# June
MOD13Q1_06 = ee.ImageCollection('MODIS/006/MOD13Q1').filter(ee.Filter.date('2021-06-01', '2021-07-01'))
ndvi_06 = MOD13Q1_06.select('NDVI').mean().multiply(0.0001).unmask(-9999).rename('ndvi_06')# Normalized Difference Vegetation Index
evi_06 = MOD13Q1_06.select('EVI').mean().multiply(0.0001).unmask(-9999).rename('evi_06')# Enhanced Vegetation Index

# July
MOD13Q1_07 = ee.ImageCollection('MODIS/006/MOD13Q1').filter(ee.Filter.date('2021-07-01', '2021-08-01'))
ndvi_07 = MOD13Q1_07.select('NDVI').mean().multiply(0.0001).unmask(-9999).rename('ndvi_07')# Normalized Difference Vegetation Index
evi_07 = MOD13Q1_07.select('EVI').mean().multiply(0.0001).unmask(-9999).rename('evi_07')# Enhanced Vegetation Index

# August
MOD13Q1_08 = ee.ImageCollection('MODIS/006/MOD13Q1').filter(ee.Filter.date('2021-08-01', '2021-09-01'))
ndvi_08 = MOD13Q1_08.select('NDVI').mean().multiply(0.0001).unmask(-9999).rename('ndvi_08')# Normalized Difference Vegetation Index
evi_08 = MOD13Q1_08.select('EVI').mean().multiply(0.0001).unmask(-9999).rename('evi_08')# Enhanced Vegetation Index

# September
MOD13Q1_09 = ee.ImageCollection('MODIS/006/MOD13Q1').filter(ee.Filter.date('2021-09-01', '2021-10-01'))
ndvi_09 = MOD13Q1_09.select('NDVI').mean().multiply(0.0001).unmask(-9999).rename('ndvi_09')# Normalized Difference Vegetation Index
evi_09 = MOD13Q1_09.select('EVI').mean().multiply(0.0001).unmask(-9999).rename('evi_09')# Enhanced Vegetation Index

# October
MOD13Q1_10 = ee.ImageCollection('MODIS/006/MOD13Q1').filter(ee.Filter.date('2021-10-01', '2021-11-01'))
ndvi_10 = MOD13Q1_10.select('NDVI').mean().multiply(0.0001).unmask(-9999).rename('ndvi_10')# Normalized Difference Vegetation Index
evi_10 = MOD13Q1_10.select('EVI').mean().multiply(0.0001).unmask(-9999).rename('evi_10')# Enhanced Vegetation Index

# Exporting VIs part
compositeOfInterest3 = ndvi_lt.addBands(evi_lt)\
.addBands(ndvi_03).addBands(evi_03)\
.addBands(ndvi_04).addBands(evi_04)\
.addBands(ndvi_05).addBands(evi_05)\
.addBands(ndvi_06).addBands(evi_06)\
.addBands(ndvi_07).addBands(evi_07)\
.addBands(ndvi_08).addBands(evi_08)\
.addBands(ndvi_09).addBands(evi_09)\
.addBands(ndvi_10).addBands(evi_10)

# Sampling
PtsSampled3 = compositeOfInterest3.sampleRegions(collection= PtsToSample,scale= 250)

# Export to drive
taskParams = {'driveFolder': 'TRISTAN','fileFormat': 'CSV'}
task = ee.batch.Export.table.toDrive(PtsSampled3,str('PtsSampled3'),**taskParams)
task.start()

# %%
# Computing LAI
# Long-term
MCD15A3H_lt = ee.ImageCollection('MODIS/006/MCD15A3H').filter(ee.Filter.date('2016-01-01', '2021-01-01'))
lai_lt = MCD15A3H_lt.select('Lai').mean().multiply(0.1).unmask(-9999).rename('lai_lt')# leaf area index
Fpar_lt = MCD15A3H_lt.select('Fpar').mean().multiply(0.01).unmask(-9999).rename('fpar_lt')# Fraction of Absorbed Photosynthetically Active Radiation absorbed by the green elements of a vegetation canopy 400-700nm

# March
MCD15A3H_03 = ee.ImageCollection('MODIS/006/MCD15A3H').filter(ee.Filter.date('2021-03-01', '2021-04-01'))
lai_03 = MCD15A3H_03.select('Lai').mean().multiply(0.1).unmask(-9999).rename('lai_03')# leaf area index
Fpar_03 = MCD15A3H_03.select('Fpar').mean().multiply(0.01).unmask(-9999).rename('fpar_03')# Fraction of Absorbed Photosynthetically Active Radiation absorbed by the green elements of a vegetation canopy 400-700nm

# April
MCD15A3H_04 = ee.ImageCollection('MODIS/006/MCD15A3H').filter(ee.Filter.date('2021-04-01', '2021-05-01'))
lai_04 = MCD15A3H_04.select('Lai').mean().multiply(0.1).unmask(-9999).rename('lai_04')# leaf area index
Fpar_04 = MCD15A3H_04.select('Fpar').mean().multiply(0.01).unmask(-9999).rename('fpar_04')# Fraction of Absorbed Photosynthetically Active Radiation absorbed by the green elements of a vegetation canopy 400-700nm

# May
MCD15A3H_05 = ee.ImageCollection('MODIS/006/MCD15A3H').filter(ee.Filter.date('2021-05-01', '2021-06-01'))
lai_05 = MCD15A3H_05.select('Lai').mean().multiply(0.1).unmask(-9999).rename('lai_05')# leaf area index
Fpar_05 = MCD15A3H_05.select('Fpar').mean().multiply(0.01).unmask(-9999).rename('fpar_05')# Fraction of Absorbed Photosynthetically Active Radiation absorbed by the green elements of a vegetation canopy 400-700nm

# June
MCD15A3H_06 = ee.ImageCollection('MODIS/006/MCD15A3H').filter(ee.Filter.date('2021-06-01', '2021-07-01'))
lai_06 = MCD15A3H_06.select('Lai').mean().multiply(0.1).unmask(-9999).rename('lai_06')# leaf area index
Fpar_06 = MCD15A3H_06.select('Fpar').mean().multiply(0.01).unmask(-9999).rename('fpar_06')# Fraction of Absorbed Photosynthetically Active Radiation absorbed by the green elements of a vegetation canopy 400-700nm

# July
MCD15A3H_07 = ee.ImageCollection('MODIS/006/MCD15A3H').filter(ee.Filter.date('2021-07-01', '2021-08-01'))
lai_07 = MCD15A3H_07.select('Lai').mean().multiply(0.1).unmask(-9999).rename('lai_07')# leaf area index
Fpar_07 = MCD15A3H_07.select('Fpar').mean().multiply(0.01).unmask(-9999).rename('fpar_07')# Fraction of Absorbed Photosynthetically Active Radiation absorbed by the green elements of a vegetation canopy 400-700nm

# August
MCD15A3H_08 = ee.ImageCollection('MODIS/006/MCD15A3H').filter(ee.Filter.date('2021-08-01', '2021-09-01'))
lai_08 = MCD15A3H_08.select('Lai').mean().multiply(0.1).unmask(-9999).rename('lai_08')# leaf area index
Fpar_08 = MCD15A3H_08.select('Fpar').mean().multiply(0.01).unmask(-9999).rename('fpar_08')# Fraction of Absorbed Photosynthetically Active Radiation absorbed by the green elements of a vegetation canopy 400-700nm

# September
MCD15A3H_09 = ee.ImageCollection('MODIS/006/MCD15A3H').filter(ee.Filter.date('2021-09-01', '2021-10-01'))
lai_09 = MCD15A3H_09.select('Lai').mean().multiply(0.1).unmask(-9999).rename('lai_09')# leaf area index
Fpar_09 = MCD15A3H_09.select('Fpar').mean().multiply(0.01).unmask(-9999).rename('fpar_09')# Fraction of Absorbed Photosynthetically Active Radiation absorbed by the green elements of a vegetation canopy 400-700nm

# October
MCD15A3H_10 = ee.ImageCollection('MODIS/006/MCD15A3H').filter(ee.Filter.date('2021-10-01', '2021-11-01'))
lai_10 = MCD15A3H_10.select('Lai').mean().multiply(0.1).unmask(-9999).rename('lai_10')# leaf area index
Fpar_10 = MCD15A3H_10.select('Fpar').mean().multiply(0.01).unmask(-9999).rename('fpar_10')# Fraction of Absorbed Photosynthetically Active Radiation absorbed by the green elements of a vegetation canopy 400-700nm

# Exporting LAI part
compositeOfInterest4 = lai_lt.addBands(Fpar_lt)\
.addBands(lai_03).addBands(Fpar_03)\
.addBands(lai_04).addBands(Fpar_04)\
.addBands(lai_05).addBands(Fpar_05)\
.addBands(lai_06).addBands(Fpar_06)\
.addBands(lai_07).addBands(Fpar_07)\
.addBands(lai_08).addBands(Fpar_08)\
.addBands(lai_09).addBands(Fpar_09)\
.addBands(lai_10).addBands(Fpar_10)

# Sampling
PtsSampled4 = compositeOfInterest4.sampleRegions(collection= PtsToSample,scale= 250)

# Export to drive
taskParams = {'driveFolder': 'TRISTAN','fileFormat': 'CSV'}
task = ee.batch.Export.table.toDrive(PtsSampled4,str('PtsSampled4'),**taskParams)
task.start()

# %%
# Computing productivity variables GPP/NPP
# Long term
MOD17A2H_lt = ee.ImageCollection('MODIS/006/MOD17A2H').filter(ee.Filter.date('2016-01-01', '2021-01-01'))
gpp_lt = MOD17A2H_lt.select('Gpp').mean().multiply(0.0001).unmask(-9999).rename('gpp_lt')# Gross primary production in kg*C/m^2
npp_lt = MOD17A2H_lt.select('PsnNet').mean().multiply(0.0001).unmask(-9999).rename('npp_lt')# Net photosynthesis in kg*C/m^2

# March
MOD17A2H_03 = ee.ImageCollection('MODIS/006/MOD17A2H').filter(ee.Filter.date('2021-03-01', '2021-04-01'))
gpp_03 = MOD17A2H_03.select('Gpp').mean().multiply(0.0001).unmask(-9999).rename('gpp_03')# Gross primary production in kg*C/m^2
npp_03 = MOD17A2H_03.select('PsnNet').mean().multiply(0.0001).unmask(-9999).rename('npp_03')# Net photosynthesis in kg*C/m^2

# April
MOD17A2H_04 = ee.ImageCollection('MODIS/006/MOD17A2H').filter(ee.Filter.date('2021-04-01', '2021-05-01'))
gpp_04 = MOD17A2H_04.select('Gpp').mean().multiply(0.0001).unmask(-9999).rename('gpp_04')# Gross primary production in kg*C/m^2
npp_04 = MOD17A2H_04.select('PsnNet').mean().multiply(0.0001).unmask(-9999).rename('npp_04')# Net photosynthesis in kg*C/m^2

# May
MOD17A2H_05 = ee.ImageCollection('MODIS/006/MOD17A2H').filter(ee.Filter.date('2021-05-01', '2021-06-01'))
gpp_05 = MOD17A2H_05.select('Gpp').mean().multiply(0.0001).unmask(-9999).rename('gpp_05')# Gross primary production in kg*C/m^2
npp_05 = MOD17A2H_05.select('PsnNet').mean().multiply(0.0001).unmask(-9999).rename('npp_05')# Net photosynthesis in kg*C/m^2

# June
MOD17A2H_06 = ee.ImageCollection('MODIS/006/MOD17A2H').filter(ee.Filter.date('2021-06-01', '2021-07-01'))
gpp_06 = MOD17A2H_06.select('Gpp').mean().multiply(0.0001).unmask(-9999).rename('gpp_06')# Gross primary production in kg*C/m^2
npp_06 = MOD17A2H_06.select('PsnNet').mean().multiply(0.0001).unmask(-9999).rename('npp_06')# Net photosynthesis in kg*C/m^2

# July
MOD17A2H_07 = ee.ImageCollection('MODIS/006/MOD17A2H').filter(ee.Filter.date('2021-07-01', '2021-08-01'))
gpp_07 = MOD17A2H_07.select('Gpp').mean().multiply(0.0001).unmask(-9999).rename('gpp_07')# Gross primary production in kg*C/m^2
npp_07 = MOD17A2H_07.select('PsnNet').mean().multiply(0.0001).unmask(-9999).rename('npp_07')# Net photosynthesis in kg*C/m^2

# August
MOD17A2H_08 = ee.ImageCollection('MODIS/006/MOD17A2H').filter(ee.Filter.date('2021-08-01', '2021-09-01'))
gpp_08 = MOD17A2H_08.select('Gpp').mean().multiply(0.0001).unmask(-9999).rename('gpp_08')# Gross primary production in kg*C/m^2
npp_08 = MOD17A2H_08.select('PsnNet').mean().multiply(0.0001).unmask(-9999).rename('npp_08')# Net photosynthesis in kg*C/m^2

# September
MOD17A2H_09 = ee.ImageCollection('MODIS/006/MOD17A2H').filter(ee.Filter.date('2021-09-01', '2021-10-01'))
gpp_09 = MOD17A2H_09.select('Gpp').mean().multiply(0.0001).unmask(-9999).rename('gpp_09')# Gross primary production in kg*C/m^2
npp_09 = MOD17A2H_09.select('PsnNet').mean().multiply(0.0001).unmask(-9999).rename('npp_09')# Net photosynthesis in kg*C/m^2

# October
MOD17A2H_10 = ee.ImageCollection('MODIS/006/MOD17A2H').filter(ee.Filter.date('2021-10-01', '2021-11-01'))
gpp_10 = MOD17A2H_10.select('Gpp').mean().multiply(0.0001).unmask(-9999).rename('gpp_10')# Gross primary production in kg*C/m^2
npp_10 = MOD17A2H_10.select('PsnNet').mean().multiply(0.0001).unmask(-9999).rename('npp_10')# Net photosynthesis in kg*C/m^2

# Exporting vegetation productivity and Human part
compositeOfInterest5 = gpp_lt.addBands(npp_lt)\
.addBands(gpp_03).addBands(npp_03)\
.addBands(gpp_04).addBands(npp_04)\
.addBands(gpp_05).addBands(npp_05)\
.addBands(gpp_06).addBands(npp_06)\
.addBands(gpp_07).addBands(npp_07)\
.addBands(gpp_08).addBands(npp_08)\
.addBands(gpp_09).addBands(npp_09)\
.addBands(gpp_10).addBands(npp_10)

# Sampling
PtsSampled5 = compositeOfInterest5.sampleRegions(collection= PtsToSample,scale= 250)

# Export to drive
taskParams = {'driveFolder': 'TRISTAN','fileFormat': 'CSV'}
task = ee.batch.Export.table.toDrive(PtsSampled5,str('PtsSampled5'),**taskParams)
task.start()

# %%
# Computing totopgraphic variables
GMTED = ee.Image('USGS/GMTED2010_FULL')
height = GMTED.select('min').unmask(-9999).rename('height')# Elevation in metres

# Sampling
PtsSampled6 = height.sampleRegions(collection= PtsToSample,scale= 250)

# Export to drive
taskParams = {'driveFolder': 'TRISTAN','fileFormat': 'CSV'}
task = ee.batch.Export.table.toDrive(PtsSampled6,str('PtsSampled6'),**taskParams)
task.start()

# %%
# Computing Human variables: Global Human Modification
CSP = ee.ImageCollection("CSP/HM/GlobalHumanModification").first()
gHM = CSP.select('gHM').unmask(-9999).rename('gHM')# cumulative measure of human modification of terrestrial lands globally at 1 square-kilometer resolution in km^2

# Sampling
PtsSampled7 = gHM.sampleRegions(collection= PtsToSample,scale= 250)

# Export to drive
taskParams = {'driveFolder': 'TRISTAN','fileFormat': 'CSV'}
task = ee.batch.Export.table.toDrive(PtsSampled7,str('PtsSampled7'),**taskParams)
task.start()

# %%
# Import all parts from drive and merge them
import pandas as pd

# Part 0
url='https://drive.google.com/file/d/10t3tss5ndHwQOkJkxLd36VDAanyoHivc/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df0 = pd.read_csv(url)
df0 = df0.drop(['system:index','.geo'], axis=1)

# Part 1
url='https://drive.google.com/file/d/1tpr5tzIxR5ZAmMgKNI8P-mA3UKlnct3W/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df1 = pd.read_csv(url)
df1 = df1.drop(['system:index','Country','name','Sample','X', 'Y','.geo'], axis=1)

# Part 2
url='https://drive.google.com/file/d/1vYrHjj0W7BY8M3Z4fLjDdq58vuBU-PQ4/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df2 = pd.read_csv(url)
df2 = df2.drop(['system:index','Country','name','Sample','X', 'Y','.geo'], axis=1)

# Part 3
url='https://drive.google.com/file/d/12VbD1YLlfqrcb42PNCIIkJKm2xeq8O_h/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df3 = pd.read_csv(url)
df3 = df3.drop(['system:index','Country','name','Sample','X', 'Y','.geo'], axis=1)

# Part 4
url='https://drive.google.com/file/d/1ZC8Eq4au4OEnR6AGejXeeFUyCHx12hmE/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df4 = pd.read_csv(url)
df4 = df4.drop(['system:index','Country','name','Sample','X', 'Y','.geo'], axis=1)

# Part 5
url='https://drive.google.com/file/d/1qiSzGsP0vPTJgmFp9EXeGpH2GsRIs_Mo/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df5 = pd.read_csv(url)
df5 = df5.drop(['system:index','Country','name','Sample','X', 'Y','.geo'], axis=1)

# Part 6
url='https://drive.google.com/file/d/1NSLAQ7QTNsWTQujpqKCDhP_-RGSCssXB/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df6 = pd.read_csv(url)
df6 = df6.drop(['system:index','Country','name','Sample','X', 'Y','.geo'], axis=1)

# Part 7
url='https://drive.google.com/file/d/11TY2mr_vCXbiyCUgoXZUGHS_gZCungFJ/view?usp=sharing'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
df7 = pd.read_csv(url)
df7 = df7.drop(['system:index','Country','name','Sample','X', 'Y','.geo'], axis=1)

# Merge
df_merged = pd.concat([df0, df1, df2, df3, df4, df5, df6, df7], axis=1, join='outer')

# Export
df_merged.to_csv('D:/MAPP/ptsSampled.csv', index=False)

# %%
df_merged
# Out:
#          Country  Sample           X          Y  aet_03  aet_04  aet_05  \
# 0         Alaska      62 -148.296200  64.703450     0.0     1.5    83.9
# 1         Alaska      63 -148.294900  64.702940     0.0     1.5    83.9
# 2         Alaska      64 -148.292800  64.702390     0.0     1.5    83.9
# 3         Alaska      65 -148.312500  64.700990     0.0     1.5    83.9
# 4         Alaska      66 -148.314500  64.700150     0.0     1.5    83.9
# ..           ...     ...         ...        ...     ...     ...     ...
# 226  Switzerland     171    8.701390  46.547220     0.0     0.0    12.5
# 227  Switzerland     173    6.665000  47.005833    35.1    65.3    81.6
# 228  Switzerland     174    7.043611  47.238333    29.0    62.4    78.9
# 229        Wales      78   -3.881500  52.903700    31.1    46.6    65.2
# 230        Wales      79   -4.011300  52.502300    37.7    38.2    72.1
#
#      aet_06  aet_07  aet_08  ...    npp_04    npp_05    npp_06    npp_07  \
# ...
